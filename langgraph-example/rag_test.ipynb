# %%
import bs4
from langchain_community.document_loaders import WebBaseLoader
from langchain_chroma import Chroma
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
import os
from dotenv import load_dotenv
load_dotenv()
OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY")
if not OPENAI_API_KEY and os.path.exists("api_key.txt"):
    with open("api_key.txt", "r", encoding="utf-8") as f:
        OPENAI_API_KEY = f.read().strip()
    os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY
if not OPENAI_API_KEY:
    raise RuntimeError("❌ OPENAI_API_KEY가 설정되어 있지 않습니다. .env 또는 api_key.txt를 확인하세요.")
# Out:
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# Cell In[15], line 34
#
#      31 text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
#
#      32 splits = text_splitter.split_documents(docs)
#
# ---> 34 vectorstore = Chroma.from_documents(
#
#      35     documents=splits,
#
#      36     embedding=OpenAIEmbeddings(model='text-embedding-3-small', api_key=OPENAI_API_KEY),
#
#      37     persist_directory="./rag_arxiv_db"  # <-- 안전하게 디렉토리 지정
#
#      38 )
#
#      40 retriever = vectorstore.as_retriever(search_kwargs={"k": 3})
#
#      42 # ✅ 3. Define the model
#
#
#
# File c:\Users\cholab1\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain_chroma\vectorstores.py:1377, in Chroma.from_documents(cls, documents, embedding, ids, collection_name, persist_directory, host, port, headers, chroma_cloud_api_key, tenant, database, client_settings, client, collection_metadata, collection_configuration, ssl, **kwargs)
#
#    1375 if ids is None:
#
#    1376     ids = [doc.id if doc.id else str(uuid.uuid4()) for doc in documents]
#
# -> 1377 return cls.from_texts(
#
#    1378     texts=texts,
#
#    1379     embedding=embedding,
#
#    1380     metadatas=metadatas,
#
#    1381     ids=ids,
#
#    1382     collection_name=collection_name,
#
#    1383     persist_directory=persist_directory,
#
#    1384     host=host,
#
#    1385     port=port,
#
#    1386     ssl=ssl,
#
#    1387     headers=headers,
#
#    1388     chroma_cloud_api_key=chroma_cloud_api_key,
#
#    1389     tenant=tenant,
#
#    1390     database=database,
#
#    1391     client_settings=client_settings,
#
#    1392     client=client,
#
#    1393     collection_metadata=collection_metadata,
#
#    1394     collection_configuration=collection_configuration,
#
#    1395     **kwargs,
#
#    1396 )
#
#
#
# File c:\Users\cholab1\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain_chroma\vectorstores.py:1311, in Chroma.from_texts(cls, texts, embedding, metadatas, ids, collection_name, persist_directory, host, port, headers, chroma_cloud_api_key, tenant, database, client_settings, client, collection_metadata, collection_configuration, ssl, **kwargs)
#
#    1303     from chromadb.utils.batch_utils import create_batches
#
#    1305     for batch in create_batches(
#
#    1306         api=chroma_collection._client,
#
#    1307         ids=ids,
#
#    1308         metadatas=metadatas,  # type: ignore[arg-type]
#
#    1309         documents=texts,
#
#    1310     ):
#
# -> 1311         chroma_collection.add_texts(
#
#    1312             texts=batch[3] if batch[3] else [],
#
#    1313             metadatas=batch[2] if batch[2] else None,  # type: ignore[arg-type]
#
#    1314             ids=batch[0],
#
#    1315         )
#
#    1316 else:
#
#    1317     chroma_collection.add_texts(texts=texts, metadatas=metadatas, ids=ids)
#
#
#
# File c:\Users\cholab1\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain_chroma\vectorstores.py:670, in Chroma.add_texts(self, texts, metadatas, ids, **kwargs)
#
#     664         self._collection.upsert(
#
#     665             embeddings=embeddings_without_metadatas,  # type: ignore[arg-type]
#
#     666             documents=texts_without_metadatas,
#
#     667             ids=ids_without_metadatas,
#
#     668         )
#
#     669 else:
#
# --> 670     self._collection.upsert(
#
#     671         embeddings=embeddings,  # type: ignore[arg-type]
#
#     672         documents=texts,
#
#     673         ids=ids,
#
#     674     )
#
#     675 return ids
#
#
#
# File c:\Users\cholab1\AppData\Local\Programs\Python\Python310\lib\site-packages\chromadb\api\models\Collection.py:442, in Collection.upsert(self, ids, embeddings, metadatas, documents, images, uris)
#
#     417 def upsert(
#
#     418     self,
#
#     419     ids: OneOrMany[ID],
#
#    (...)
#
#     429     uris: Optional[OneOrMany[URI]] = None,
#
#     430 ) -> None:
#
#     431     """Update the embeddings, metadatas or documents for provided ids, or create them if they don't exist.
#
#     432
#
#     433     Args:
#
#    (...)
#
#     440         None
#
#     441     """
#
# --> 442     upsert_request = self._validate_and_prepare_upsert_request(
#
#     443         ids=ids,
#
#     444         embeddings=embeddings,
#
#     445         metadatas=metadatas,
#
#     446         documents=documents,
#
#     447         images=images,
#
#     448         uris=uris,
#
#     449     )
#
#     451     self._client._upsert(
#
#     452         collection_id=self.id,
#
#     453         ids=upsert_request["ids"],
#
#    (...)
#
#     459         database=self.database,
#
#     460     )
#
#
#
# File c:\Users\cholab1\AppData\Local\Programs\Python\Python310\lib\site-packages\chromadb\api\models\CollectionCommon.py:103, in validation_context.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#
#     100 @functools.wraps(func)
#
#     101 def wrapper(self: Any, *args: Any, **kwargs: Any) -> T:
#
#     102     try:
#
# --> 103         return func(self, *args, **kwargs)
#
#     104     except Exception as e:
#
#     105         msg = f"{str(e)} in {name}."
#
#
#
# File c:\Users\cholab1\AppData\Local\Programs\Python\Python310\lib\site-packages\chromadb\api\models\CollectionCommon.py:431, in CollectionCommon._validate_and_prepare_upsert_request(self, ids, embeddings, metadatas, documents, images, uris)
#
#     415 @validation_context("upsert")
#
#     416 def _validate_and_prepare_upsert_request(
#
#     417     self,
#
#    (...)
#
#     429 ) -> UpsertRequest:
#
#     430     # Unpack
#
# --> 431     upsert_records = normalize_insert_record_set(
#
#     432         ids=ids,
#
#     433         embeddings=embeddings,
#
#     434         metadatas=metadatas,
#
#     435         documents=documents,
#
#     436         images=images,
#
#     437         uris=uris,
#
#     438     )
#
#     440     # Validate
#
#     441     validate_insert_record_set(record_set=upsert_records)
#
#
#
# File c:\Users\cholab1\AppData\Local\Programs\Python\Python310\lib\site-packages\chromadb\api\types.py:337, in normalize_insert_record_set(ids, embeddings, metadatas, documents, images, uris)
#
#     321 def normalize_insert_record_set(
#
#     322     ids: OneOrMany[ID],
#
#     323     embeddings: Optional[
#
#    (...)
#
#     332     uris: Optional[OneOrMany[URI]] = None,
#
#     333 ) -> InsertRecordSet:
#
#     334     """
#
#     335     Unpacks and normalizes the fields of an InsertRecordSet.
#
#     336     """
#
# --> 337     base_record_set = normalize_base_record_set(
#
#     338         embeddings=embeddings, documents=documents, images=images, uris=uris
#
#     339     )
#
#     341     return InsertRecordSet(
#
#     342         ids=cast(IDs, maybe_cast_one_to_many(ids)),
#
#     343         metadatas=maybe_cast_one_to_many(metadatas),
#
#    (...)
#
#     347         uris=base_record_set["uris"],
#
#     348     )
#
#
#
# File c:\Users\cholab1\AppData\Local\Programs\Python\Python310\lib\site-packages\chromadb\api\types.py:314, in normalize_base_record_set(embeddings, documents, images, uris)
#
#     303 def normalize_base_record_set(
#
#     304     embeddings: Optional[Union[OneOrMany[Embedding], OneOrMany[PyEmbedding]]] = None,
#
#     305     documents: Optional[OneOrMany[Document]] = None,
#
#     306     images: Optional[OneOrMany[Image]] = None,
#
#     307     uris: Optional[OneOrMany[URI]] = None,
#
#     308 ) -> BaseRecordSet:
#
#     309     """
#
#     310     Unpacks and normalizes the fields of a BaseRecordSet.
#
#     311     """
#
#     313     return BaseRecordSet(
#
# --> 314         embeddings=normalize_embeddings(embeddings),
#
#     315         documents=maybe_cast_one_to_many(documents),
#
#     316         images=maybe_cast_one_to_many(images),
#
#     317         uris=maybe_cast_one_to_many(uris),
#
#     318     )
#
#
#
# File c:\Users\cholab1\AppData\Local\Programs\Python\Python310\lib\site-packages\chromadb\api\types.py:217, in normalize_embeddings(target)
#
#     214     return None
#
#     216 if len(target) == 0:
#
# --> 217     raise ValueError(
#
#     218         f"Expected Embeddings to be non-empty list or numpy array, got {target}"
#
#     219     )
#
#     221 if isinstance(target, np.ndarray):
#
#     222     if target.ndim == 1:
#
#
#
# ValueError: Expected Embeddings to be non-empty list or numpy array, got [] in upsert.

# %%
# ✅ 1. Load the paper from arXiv
loader = WebBaseLoader(
    web_paths=("https://www.cancer.go.kr/lay1/S1T648C650/contents.do",),
    bs_kwargs=dict(
        parse_only=bs4.SoupStrainer("div", class_="cont_txt")  # ✅ 핵심 수정
    ),
)
docs = loader.load()

# %%
# ✅ 2. Chunk and embed
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
splits = text_splitter.split_documents(docs)

vectorstore = Chroma.from_documents(
    documents=splits,
    embedding=OpenAIEmbeddings(model='text-embedding-3-small', api_key=OPENAI_API_KEY),
    persist_directory="./rag_arxiv_db"  # <-- 안전하게 디렉토리 지정
)

retriever = vectorstore.as_retriever(search_kwargs={"k": 3})

# ✅ 3. Define the model
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0, api_key=OPENAI_API_KEY)

# ✅ 4. Define your RAG prompt manually (no hub dependency)
prompt = ChatPromptTemplate.from_template(
    """
You are an expert research assistant. 
Using the context below, answer the user question clearly and concisely.

<context>
{context}
</context>

Question: {question}
Answer:
"""
)

# ✅ 5. Helper: format retriever output
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# ✅ 6. Build the chain
rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# ✅ 7. Test run
response = rag_chain.invoke("한국의 전체 암환자 5년 생존율은 얼마인가요?")
print(response)
